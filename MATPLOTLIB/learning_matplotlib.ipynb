# %% [markdown]
# #### =========== LEARNING MATPLOTLIB & SEABORN FOR VISUALISATIONS ================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys, pathlib
from pathlib import Path

# %% [markdown]
# ### 1- Chargement des données avec Pandas

# %%
df_crime = pd.read_csv('../DATA/crime_2024.csv')

# %%
# les données sur les crimes en 2024 en californie
df_crime.head(5) # les 05 premières lignes du dataframe
# Out:
#          ID Case Number                    Date  \
# 0  13709672    JJ101940  12/31/2024 11:58:00 PM
# 1  13707925    JJ100089  12/31/2024 11:56:00 PM
# 2  13708038    JJ100035  12/31/2024 11:55:00 PM
# 3  13709164    JJ101392  12/31/2024 11:53:00 PM
# 4  13707823    JJ100020  12/31/2024 11:50:00 PM
#
#                                  Block  IUCR       Primary Type  \
# 0                      014XX E 68TH ST  1310    CRIMINAL DAMAGE
# 1  047XX S DR MARTIN LUTHER KING JR DR  1365  CRIMINAL TRESPASS
# 2                   077XX S CICERO AVE  0498            BATTERY
# 3                066XX S GREENWOOD AVE  1320    CRIMINAL DAMAGE
# 4                   012XX N MENARD AVE  0460            BATTERY
#
#                                          Description Location Description  \
# 0                                        TO PROPERTY            APARTMENT
# 1                                       TO RESIDENCE            APARTMENT
# ...

# %% [markdown]
# #### 3- EXploratoire des données (EDA)

# %%
## les analyses exploratoires des données
print(f"Les colonnes de dataframe :\n {df_crime.columns}")

# les types des colonnes de dataframe 
print(f"Les types de colonne de dataframe :\n {df_crime.dtypes}")

# les variables manquantes
print(f"Les valeurs manquantes :\n {df_crime.isna().sum()}") # ou vous pouvez utiliser df.isnull().sum()

# les dimensions du dataframe
print(f"Les dimensions de dataframe :\n {df_crime.shape}")
# Out:
# Les colonnes de dataframe :
#  Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')
# Les types de colonne de dataframe :
#  ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                      int64
# Community Area            int64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# ...

# %%
df_crime['Latitude'] = df_crime.Latitude.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_crime['Latitude'] = df_crime.Latitude.astype('int64')
#
# File ~/Data-science/env/lib/python3.12/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~/Data-science/env/lib/python3.12/site-packages/pandas/core/internals/managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
# ...
