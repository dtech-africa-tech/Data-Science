# %% [markdown]
# #### Installation de pandas

# %% [markdown]
# pip install -U pandas

# %% [markdown]
# #### importation de pandas et numpy

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Chargement de data

# %%
## create of dataframe

df = pd.DataFrame({
    "AGe":[12, 15, 16, 14,70, 15, 18, 52, 17],
    "BMI":[12.4, 15.68, 18.4, "", 75, 15.5, 14.8, 19.56, 0.33],
    "Diabetes":["No", "Yes", 'No', 'NAN', "Yes", "No", "no", "No", "Yes"]
})

df
# Out:
#    AGe    BMI Diabetes
# 0   12   12.4       No
# 1   15  15.68      Yes
# 2   16   18.4       No
# 3   14             NAN
# 4   70     75      Yes
# 5   15   15.5       No
# 6   18   14.8       no
# 7   52  19.56       No
# 8   17   0.33      Yes

# %%
### 05 premieres lignes d'un dataframe

df.head(5)
# Out:
#    AGe    BMI Diabetes
# 0   12   12.4       No
# 1   15  15.68      Yes
# 2   16   18.4       No
# 3   14             NAN
# 4   70     75      Yes

# %%
### verifier la dimension de mon dataframe

df.shape
# Out:
# (9, 3)

# %%
### types de donnnées de mon dataframe
df.dtypes
# Out:
# AGe          int64
# BMI         object
# Diabetes    object
# dtype: object

# %%
### verfieles valeurs manquantes 

df.isnull() # df.isna()
# Out:
#      AGe    BMI  Diabetes
# 0  False  False     False
# 1  False  False     False
# 2  False  False     False
# 3  False  False     False
# 4  False  False     False
# 5  False  False     False
# 6  False  False     False
# 7  False  False     False
# 8  False  False     False

# %%
    ### nombres total de valeurs manquantes
    
df.isnull().sum()
# Out:
# AGe         0
# BMI         0
# Diabetes    0
# dtype: int64

# %%
### format d'un dataframe 

# .csv, .xlsx(excel), .html, .parquet

# %%
data = pd.read_csv("../DATA/Crimes_-_2024_20251107.csv")

##df = pd.read_excel("")

# les premieres lignes de la dataframe
data.head(10)
# Out:
#          ID Case Number                    Date  \
# 0  13709672    JJ101940  12/31/2024 11:58:00 PM
# 1  13707925    JJ100089  12/31/2024 11:56:00 PM
# 2  13708038    JJ100035  12/31/2024 11:55:00 PM
# 3  13709164    JJ101392  12/31/2024 11:53:00 PM
# 4  13707823    JJ100020  12/31/2024 11:50:00 PM
# 5  13707839    JJ100021  12/31/2024 11:46:00 PM
# 6  13707986    JJ100019  12/31/2024 11:45:00 PM
# 7  13707849    JJ100011  12/31/2024 11:45:00 PM
# 8  13707847    JJ100007  12/31/2024 11:42:00 PM
# 9  13707836    JJ100034  12/31/2024 11:40:00 PM
#
#                                  Block  IUCR         Primary Type  \
# 0                      014XX E 68TH ST  1310      CRIMINAL DAMAGE
# 1  047XX S DR MARTIN LUTHER KING JR DR  1365    CRIMINAL TRESPASS
# 2                   077XX S CICERO AVE  0498              BATTERY
# 3                066XX S GREENWOOD AVE  1320      CRIMINAL DAMAGE
# 4                   012XX N MENARD AVE  0460              BATTERY
# ...

# %%
### la dimensions
data.shape
# Out:
# (258792, 22)

# %%
data.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                      int64
# Community Area            int64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
# les valeurs manquantes

data.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description    1090
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       0
# Community Area             0
# FBI Code                   0
# X Coordinate            1235
# Y Coordinate            1235
# Year                       0
# Updated On                 0
# Latitude                1235
# Longitude               1235
# Location                1235
# dtype: int64

# %%
missing_values = data.isnull().sum()

# pourcentage
ratio = missing_values *100/len(data)

df_missing = pd.DataFrame(
    {
    "missing_total": missing_values,
    "pourcentage": ratio
    }
)

df_missing
# Out:
#                       missing_total  pourcentage
# ID                                0     0.000000
# Case Number                       0     0.000000
# Date                              0     0.000000
# Block                             0     0.000000
# IUCR                              0     0.000000
# Primary Type                      0     0.000000
# Description                       0     0.000000
# Location Description           1090     0.421188
# Arrest                            0     0.000000
# Domestic                          0     0.000000
# Beat                              0     0.000000
# District                          0     0.000000
# Ward                              0     0.000000
# Community Area                    0     0.000000
# FBI Code                          0     0.000000
# X Coordinate                   1235     0.477217
# Y Coordinate                   1235     0.477217
# Year                              0     0.000000
# ...

# %%
data.isna().sum()

# %%
### analyse descriptives

data.describe()
# Out:
#                  ID           Beat       District           Ward  \
# count  2.587920e+05  258792.000000  258792.000000  258792.000000
# mean   1.349158e+07    1157.200644      11.342147      23.187548
# std    6.534467e+05     709.322260       7.087917      13.949805
# min    2.793200e+04     111.000000       1.000000       1.000000
# 25%    1.342528e+07     533.000000       5.000000      10.000000
# 50%    1.352165e+07    1034.000000      10.000000      23.000000
# 75%    1.361702e+07    1732.000000      17.000000      34.000000
# max    1.401934e+07    2535.000000      31.000000      50.000000
#
#        Community Area  X Coordinate  Y Coordinate      Year       Latitude  \
# count   258792.000000  2.575570e+05  2.575570e+05  258792.0  257557.000000
# mean        36.181486  1.165282e+06  1.887736e+06    2024.0      41.847531
# std         21.608969  1.616080e+04  3.153839e+04       0.0       0.086724
# min          1.000000  1.092647e+06  1.813897e+06    2024.0      41.644590
# ...

# %%
data.describe(exclude=["object", "bool"])
# Out:
#                  ID           Beat       District           Ward  \
# count  2.587920e+05  258792.000000  258792.000000  258792.000000
# mean   1.349158e+07    1157.200644      11.342147      23.187548
# std    6.534467e+05     709.322260       7.087917      13.949805
# min    2.793200e+04     111.000000       1.000000       1.000000
# 25%    1.342528e+07     533.000000       5.000000      10.000000
# 50%    1.352165e+07    1034.000000      10.000000      23.000000
# 75%    1.361702e+07    1732.000000      17.000000      34.000000
# max    1.401934e+07    2535.000000      31.000000      50.000000
#
#        Community Area  X Coordinate  Y Coordinate      Year       Latitude  \
# count   258792.000000  2.575570e+05  2.575570e+05  258792.0  257557.000000
# mean        36.181486  1.165282e+06  1.887736e+06    2024.0      41.847531
# std         21.608969  1.616080e+04  3.153839e+04       0.0       0.086724
# min          1.000000  1.092647e+06  1.813897e+06    2024.0      41.644590
# ...
